# %%
import tensorflow as tf
import numpy as np
from tensorflow import data
import shutil
import math
from datetime import datetime
from tensorflow.python.feature_column import feature_column

print(tf.__version__)
# Out:
# 1.12.0

# %% [markdown]
# ## Steps to use the TF Estimator (Train_And_Evaluate) APIs
# 1. Define dataset **metadata**
# 2. Define **data input function** to read the data from .tfrecord files + **feature processing**
# 3. Create TF **feature columns** based on metadata + **extended feature columns**
# 4. Define an **estimator** (LinearCombinedDNNRegressor) with the required **feature columns (wide/deep) & parameters**
# 7. Run an experiment using the estimator **train_and_evaluate** function to train, evaluate, and export the model
# 8. **Evaluate** the model using test data
# 9. Perform **predictions** & **serving** the exported model

# %%
MODEL_NAME = 'reg-model-06'

TRAIN_DATA_FILES_PATTERN = 'data/train-*.tfrecords'
VALID_DATA_FILES_PATTERN = 'data/valid-*.tfrecords'
TEST_DATA_FILES_PATTERN = 'data/test-*.tfrecords'

RESUME_TRAINING = False
PROCESS_FEATURES = True
EXTEND_FEATURE_COLUMNS = True
MULTI_THREADING = True

# %% [markdown]
# ## 1. Define Dataset Metadata
# * tf.example feature names and defaults
# * Numeric and categorical feature names
# * Target feature name
# * Unused features

# %%
HEADER = ['key','x','y','alpha','beta','target']
HEADER_DEFAULTS = [[0], [0.0], [0.0], ['NA'], ['NA'], [0.0]]

NUMERIC_FEATURE_NAMES = ['x', 'y']  

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {'alpha':['ax01', 'ax02'], 'beta':['bx01', 'bx02']}
CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'target'

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})

print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {}".format(TARGET_NAME))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['key', 'x', 'y', 'alpha', 'beta', 'target']
# Numeric Features: ['x', 'y']
# Categorical Features: ['alpha', 'beta']
# Target: target
# Unused Features: ['key']

# %% [markdown]
# ## 2. Define Data Input Function
# * Input .tfrecords files name pattern
# * Use TF Dataset APIs to read and process the data
# * Parse tf.exmaples  to feature tensors
# * Apply feature processing
# * Return (features, target) tensors

# %% [markdown]
# ### a. Parsing and preprocessing logic

# %%
def parse_tf_example(example_proto):

    feature_spec = {}

    for feature_name in NUMERIC_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(1), dtype=tf.float32)
    
    for feature_name in CATEGORICAL_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(1), dtype=tf.string)
    
    feature_spec[TARGET_NAME] = tf.FixedLenFeature(shape=(1), dtype=tf.float32)

    parsed_features = tf.parse_example(serialized=example_proto, features=feature_spec)
    
    target = parsed_features.pop(TARGET_NAME)
    
    return parsed_features, target


def process_features(features):
    
    # example of clipping
    features['x'] = tf.clip_by_value(features['x'], clip_value_min=-3, clip_value_max=3)
    features['y'] = tf.clip_by_value(features['y'], clip_value_min=-3, clip_value_max=3)
    
    # example of polynomial expansion
    features["x_2"] = tf.square(features['x'])
    features["y_2"] = tf.square(features['y'])
    
    # example of nonlinearity
    features["xy"] = features['x'] * features['y']
    
    # example of custom logic
    features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    features["sin_x"] = tf.sin(features['x'])
    features["cos_y"] = tf.sin(features['y'])
    
    
    
    return features

# %% [markdown]
# ### b. Data pipeline input function

# %%
def tfrecods_input_fn(files_name_pattern, mode=tf.estimator.ModeKeys.EVAL, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
    
    print("")
    print("* data input_fn:")
    print("================")
    print("Input file(s): {}".format(files_name_pattern))
    print("Batch size: {}".format(batch_size))
    print("Epoch Count: {}".format(num_epochs))
    print("Mode: {}".format(mode))
    print("Shuffle: {}".format(shuffle))
    print("================")
    print("")

    file_names = tf.matching_files(files_name_pattern)
    dataset = data.TFRecordDataset(filenames=file_names)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda tf_example: parse_tf_example(tf_example))
    
    if PROCESS_FEATURES:
        dataset = dataset.map(lambda features, target: (process_features(features), target))
        
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, target

# %%
features, target = tfrecods_input_fn(files_name_pattern="")
print("Feature read from TFRecords: {}".format(list(features.keys())))
print("Target read from TFRecords: {}".format(target))
# Out:
# * data input_fn:
# ================
# Input file(s):
# Batch size: 200
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# Feature read from TFRecords: ['alpha', 'beta', 'x', 'y', 'x_2', 'y_2', 'xy', 'dist_xy', 'sin_x', 'cos_y']
# Target read from TFRecords: Tensor("IteratorGetNext:10", shape=(?, 1), dtype=float32)

# %% [markdown]
# ## 3. Define Feature Columns
# The input numeric columns are assumed to be normalized (or have the same scale). Otherwise, a normlizer_fn, along with the normlisation params (mean, stdv or min, max) should be passed to tf.feature_column.numeric_column() constructor

# %%
def extend_feature_columns(feature_columns, hparams):
    
    num_buckets = hparams.num_buckets
    embedding_size = hparams.embedding_size

    buckets = np.linspace(-3, 3, num_buckets).tolist()

    alpha_X_beta = tf.feature_column.crossed_column(
            [feature_columns['alpha'], feature_columns['beta']], 4)

    x_bucketized = tf.feature_column.bucketized_column(
            feature_columns['x'], boundaries=buckets)

    y_bucketized = tf.feature_column.bucketized_column(
            feature_columns['y'], boundaries=buckets)

    x_bucketized_X_y_bucketized = tf.feature_column.crossed_column(
           [x_bucketized, y_bucketized], num_buckets**2)

    x_bucketized_X_y_bucketized_embedded = tf.feature_column.embedding_column(
            x_bucketized_X_y_bucketized, dimension=embedding_size)


    feature_columns['alpha_X_beta'] = alpha_X_beta
    feature_columns['x_bucketized_X_y_bucketized'] = x_bucketized_X_y_bucketized
    feature_columns['x_bucketized_X_y_bucketized_embedded'] = x_bucketized_X_y_bucketized_embedded
    
    return feature_columns
    

def get_feature_columns(hparams):
    
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = ['x_2', 'y_2', 'xy', 'dist_xy', 'sin_x', 'cos_y']
    all_numeric_feature_names = NUMERIC_FEATURE_NAMES.copy() 
    
    if PROCESS_FEATURES:
        all_numeric_feature_names += CONSTRUCTED_NUMERIC_FEATURES_NAMES

    numeric_columns = {feature_name: tf.feature_column.numeric_column(feature_name)
                       for feature_name in all_numeric_feature_names}

    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
    
    if EXTEND_FEATURE_COLUMNS:
        feature_columns = extend_feature_columns(feature_columns, hparams)
        
    return feature_columns

feature_columns = get_feature_columns(tf.contrib.training.HParams(num_buckets=5,embedding_size=3))
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'x': _NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y': _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'x_2': _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y_2': _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'xy': _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'dist_xy': _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'sin_x': _NumericColumn(key='sin_x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'cos_y': _NumericColumn(key='cos_y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'alpha': _VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'beta': _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'alpha_X_beta': _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), 'x_bucketized_X_y_bucketized': _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), 'x_bucketized_X_y_bucketized_embedded': _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), dimension=3, combiner='mean', layer_creator=<function embedding_column.<locals>._creator at 0x000000002D5A8510>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True)}

# %% [markdown]
# ## 4. Define an Estimator Creation Function

# %% [markdown]
# ### a. Get wide and deep feature columns
# * dense columns = numeric columns + embedding columns
# * categorical columns = vocabolary list columns + bucketized columns
# * sparse columns = hashed categorical columns + crossed columns
# * categorical columns => indicator columns
# * deep columns = dense columns + indicator columns
# * wide columns = categorical columns + sparse columns

# %%
def get_wide_deep_columns():
    
    feature_columns = list(get_feature_columns(hparams).values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn) |
                              isinstance(column, feature_column._EmbeddingColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )
    
    sparse_columns = list(
        filter(lambda column: isinstance(column,feature_column._HashedCategoricalColumn) |
                              isinstance(column, feature_column._CrossedColumn),
               feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    deep_feature_columns = dense_columns + indicator_columns
    wide_feature_columns = categorical_columns + sparse_columns
    
    return wide_feature_columns, deep_feature_columns

# %% [markdown]
# ### b. Define the DNNLinearCombinedRegressor

# %%
def create_estimator(run_config, hparams, print_desc=False):
    
    wide_feature_columns, deep_feature_columns = get_wide_deep_columns()
    
    estimator = tf.estimator.DNNLinearCombinedRegressor(
        
        dnn_feature_columns = deep_feature_columns,
        linear_feature_columns = wide_feature_columns,
        
        dnn_hidden_units= hparams.hidden_units,
        
        dnn_optimizer= tf.train.AdamOptimizer(),
        
        dnn_activation_fn= tf.nn.elu,
        dnn_dropout= hparams.dropout_prob,
        
        config= run_config
    )
    
    
    if print_desc:
        print("")
        print("*Estimator Type:")
        print("================")
        print(type(estimator))
        print("")
        print("*deep columns:")
        print("==============")
        print(deep_feature_columns)
        print("")
        print("wide columns:")
        print("=============")
        print(wide_feature_columns)
        print("")
    
    return estimator

# %% [markdown]
# ## 5. Run Experiment

# %% [markdown]
# ### a. Set HParam and RunConfig

# %%
TRAIN_SIZE = 12000
NUM_EPOCHS = 1000
BATCH_SIZE = 500
EVAL_AFTER_SEC = 15
TOTAL_STEPS = (TRAIN_SIZE/BATCH_SIZE)*NUM_EPOCHS

hparams  = tf.contrib.training.HParams(
    num_epochs = NUM_EPOCHS,
    batch_size = BATCH_SIZE,
    hidden_units=[16, 12, 8],
    num_buckets = 6,
    embedding_size = 3,
    max_steps = TOTAL_STEPS,
    dropout_prob = 0.001)

model_dir = 'trained_models/{}'.format(MODEL_NAME)

run_config = tf.estimator.RunConfig(
    tf_random_seed=19830610,
    model_dir=model_dir
)

print(hparams)
print("Model Directory:", run_config.model_dir)
print("")
print("Dataset Size:", TRAIN_SIZE)
print("Batch Size:", BATCH_SIZE)
print("Steps per Epoch:",TRAIN_SIZE/BATCH_SIZE)
print("Total Steps:", TOTAL_STEPS)
print("That is 1 evaluation step after each",EVAL_AFTER_SEC," training seconds")
# Out:
# [('batch_size', 500), ('dropout_prob', 0.001), ('embedding_size', 3), ('hidden_units', [16, 12, 8]), ('max_steps', 24000.0), ('num_buckets', 6), ('num_epochs', 1000)]
# Model Directory: trained_models/reg-model-06
#
# Dataset Size: 12000
# Batch Size: 500
# Steps per Epoch: 24.0
# Total Steps: 24000.0
# That is 1 evaluation step after each 15  training seconds

# %% [markdown]
# ###  b. Define Serving Function

# %%
def csv_serving_input_fn():
    
    SERVING_HEADER = ['x','y','alpha','beta']
    SERVING_HEADER_DEFAULTS = [[0.0], [0.0], ['NA'], ['NA']]

    rows_string_tensor = tf.placeholder(dtype=tf.string,
                                         shape=[None],
                                         name='csv_rows')
    
    receiver_tensor = {'csv_rows': rows_string_tensor}

    row_columns = tf.expand_dims(rows_string_tensor, -1)
    columns = tf.decode_csv(row_columns, record_defaults=SERVING_HEADER_DEFAULTS)
    features = dict(zip(SERVING_HEADER, columns))
    
    if PROCESS_FEATURES:
        features = process_features(features)

    return tf.estimator.export.ServingInputReceiver(
        features, receiver_tensor)

# %% [markdown]
# ### c. Define an Early Stopping Monitor (Hook)

# %%
class EarlyStoppingHook(tf.train.SessionRunHook):
    
    def __init__(self, early_stopping_rounds=1):
        self._best_loss = None
        self._early_stopping_rounds = early_stopping_rounds
        self._counter = 0
        
        print("")
        print("*** Early Stopping Hook: - Created")
        print("*** Early Stopping Hook:: Early Stopping Rounds: {}".format(self._early_stopping_rounds))
        print("")

    def before_run(self, run_context):
        
        graph = run_context.session.graph
        
#         tensor_name = "dnn/head/weighted_loss/Sum:0" #works!!
#         loss_tensor = graph.get_tensor_by_name(tensor_name)

        loss_tensor = graph.get_collection(tf.GraphKeys.LOSSES)[1]
        return tf.train.SessionRunArgs(loss_tensor)

    def after_run(self, run_context, run_values):
        
        last_loss = run_values.results
        
        print("")
        print("************************")
        print("** Evaluation Monitor - Early Stopping **")
        print("-----------------------------------------")
        print("Early Stopping Hook: Current loss: {}".format(str(last_loss)))
        print("Early Stopping Hook: Best loss: {}".format(str(self._best_loss)))

        if self._best_loss is None:
            self._best_loss = last_loss
            
        elif last_loss > self._best_loss:
            
            self._counter += 1
            print("Early Stopping Hook: No improvment! Counter: {}".format(self._counter))
            
            if self._counter == self._early_stopping_rounds:
                
                run_context.request_stop()
                print("Early Stopping Hook: Stop Requested: {}".format(run_context.stop_requested))
        else:
            
            self._best_loss = last_loss
            self._counter = 0
            
        print("************************")
        print("")

# %% [markdown]
# ### d. Define TrainSpec and EvaluSpec

# %%
train_spec = tf.estimator.TrainSpec(
    input_fn = lambda: tfrecods_input_fn(
        TRAIN_DATA_FILES_PATTERN,
        mode = tf.estimator.ModeKeys.TRAIN,
        num_epochs=hparams.num_epochs,
        batch_size=hparams.batch_size
    ),
    max_steps=hparams.max_steps,
    hooks=None
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = lambda: tfrecods_input_fn(
        VALID_DATA_FILES_PATTERN,
        mode=tf.estimator.ModeKeys.EVAL,
        num_epochs=1,
        batch_size=hparams.batch_size
    ),
    exporters=[tf.estimator.LatestExporter(
        name="estimate",  # the name of the folder in which the model will be exported to under export
        serving_input_receiver_fn=csv_serving_input_fn,
        exports_to_keep=1,
        as_text=True)],
    steps=None,
    #hooks=[EarlyStoppingHook(15)],
    throttle_secs = EVAL_AFTER_SEC # evalute after each 15 training seconds!
)

# %% [markdown]
# ### e. Run Experiment via train_and_evaluate

# %%
if not RESUME_TRAINING:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 
import path
path.Path(model_dir +"/export/estimate").makedirs_p()
    
tf.logging.set_verbosity(tf.logging.INFO)

time_start = datetime.utcnow() 
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 

estimator = create_estimator(run_config, hparams, True)

tf.estimator.train_and_evaluate(
    estimator=estimator,
    train_spec=train_spec, 
    eval_spec=eval_spec
)

time_end = datetime.utcnow() 
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# Removing previous artifacts...
# Experiment started at 08:44:35
# .......................................
# INFO:tensorflow:Using config: {'_model_dir': 'trained_models/reg-model-06', '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000000039B99320>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# *Estimator Type:
# ================
# <class 'tensorflow.python.estimator.canned.dnn_linear_combined.DNNLinearCombinedRegressor'>
#
# *deep columns:
# ==============
# [_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='sin_x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='cos_y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None), dimension=3, combiner='mean', layer_creator=<function embedding_column.<locals>._creator at 0x0000000039B98620>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0))]
#
# wide columns:
# =============
# [_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None)]
#
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Shuffle: True
# ================
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into trained_models/reg-model-06\model.ckpt.
# INFO:tensorflow:loss = 151164.45, step = 1
# INFO:tensorflow:global_step/sec: 125.156
# INFO:tensorflow:loss = 151910.31, step = 101 (0.800 sec)
# INFO:tensorflow:global_step/sec: 288.184
# INFO:tensorflow:loss = 135929.19, step = 201 (0.348 sec)
# INFO:tensorflow:global_step/sec: 281.69
# INFO:tensorflow:loss = 145301.61, step = 301 (0.354 sec)
# INFO:tensorflow:global_step/sec: 294.985
# INFO:tensorflow:loss = 97492.125, step = 401 (0.339 sec)
# INFO:tensorflow:global_step/sec: 246.913
# INFO:tensorflow:loss = 71769.89, step = 501 (0.405 sec)
# INFO:tensorflow:global_step/sec: 307.692
# INFO:tensorflow:loss = 70208.56, step = 601 (0.325 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 57738.574, step = 701 (0.313 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 53126.28, step = 801 (0.311 sec)
# INFO:tensorflow:global_step/sec: 315.457
# INFO:tensorflow:loss = 63063.81, step = 901 (0.317 sec)
# INFO:tensorflow:global_step/sec: 317.46
# INFO:tensorflow:loss = 46109.457, step = 1001 (0.315 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 49009.82, step = 1101 (0.309 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 40762.89, step = 1201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 322.58
# INFO:tensorflow:loss = 56658.434, step = 1301 (0.310 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 47083.61, step = 1401 (0.314 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 46737.2, step = 1501 (0.310 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 40725.836, step = 1601 (0.311 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 42477.336, step = 1701 (0.312 sec)
# INFO:tensorflow:global_step/sec: 316.456
# INFO:tensorflow:loss = 46671.38, step = 1801 (0.317 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 39649.344, step = 1901 (0.312 sec)
# INFO:tensorflow:global_step/sec: 315.458
# INFO:tensorflow:loss = 45826.785, step = 2001 (0.317 sec)
# INFO:tensorflow:global_step/sec: 295.858
# INFO:tensorflow:loss = 50081.562, step = 2101 (0.338 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 41199.113, step = 2201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 43835.52, step = 2301 (0.311 sec)
# INFO:tensorflow:global_step/sec: 314.466
# INFO:tensorflow:loss = 45859.473, step = 2401 (0.318 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 39179.02, step = 2501 (0.315 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 53701.51, step = 2601 (0.308 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 46670.98, step = 2701 (0.315 sec)
# INFO:tensorflow:global_step/sec: 284.091
# INFO:tensorflow:loss = 42050.145, step = 2801 (0.352 sec)
# INFO:tensorflow:global_step/sec: 290.698
# INFO:tensorflow:loss = 51403.086, step = 2901 (0.344 sec)
# INFO:tensorflow:global_step/sec: 266.667
# INFO:tensorflow:loss = 43955.188, step = 3001 (0.374 sec)
# INFO:tensorflow:global_step/sec: 259.74
# INFO:tensorflow:loss = 38410.39, step = 3101 (0.386 sec)
# INFO:tensorflow:global_step/sec: 310.559
# INFO:tensorflow:loss = 51768.695, step = 3201 (0.321 sec)
# INFO:tensorflow:global_step/sec: 313.48
# INFO:tensorflow:loss = 32707.598, step = 3301 (0.319 sec)
# INFO:tensorflow:global_step/sec: 317.461
# INFO:tensorflow:loss = 43590.63, step = 3401 (0.315 sec)
# INFO:tensorflow:global_step/sec: 304.878
# INFO:tensorflow:loss = 44745.953, step = 3501 (0.328 sec)
# INFO:tensorflow:global_step/sec: 295.858
# INFO:tensorflow:loss = 41627.12, step = 3601 (0.338 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 45065.918, step = 3701 (0.312 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 45378.86, step = 3801 (0.307 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 44808.05, step = 3901 (0.313 sec)
# INFO:tensorflow:global_step/sec: 316.456
# INFO:tensorflow:loss = 43936.805, step = 4001 (0.316 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 41753.086, step = 4101 (0.314 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 42697.87, step = 4201 (0.313 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 45538.773, step = 4301 (0.306 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 45003.465, step = 4401 (0.311 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 44549.062, step = 4501 (0.311 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 41616.227, step = 4601 (0.312 sec)
# INFO:tensorflow:global_step/sec: 305.81
# INFO:tensorflow:loss = 36391.133, step = 4701 (0.326 sec)
# INFO:tensorflow:global_step/sec: 294.985
# INFO:tensorflow:loss = 47928.93, step = 4801 (0.339 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 41785.344, step = 4901 (0.310 sec)
# INFO:tensorflow:global_step/sec: 306.748
# INFO:tensorflow:loss = 45245.94, step = 5001 (0.326 sec)
# INFO:tensorflow:global_step/sec: 316.456
# INFO:tensorflow:loss = 47954.273, step = 5101 (0.316 sec)
# INFO:tensorflow:global_step/sec: 294.118
# INFO:tensorflow:loss = 42334.535, step = 5201 (0.340 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 39792.21, step = 5301 (0.311 sec)
# INFO:tensorflow:global_step/sec: 259.067
# INFO:tensorflow:loss = 41465.117, step = 5401 (0.387 sec)
# INFO:tensorflow:global_step/sec: 206.186
# INFO:tensorflow:loss = 38812.934, step = 5501 (0.483 sec)
# INFO:tensorflow:global_step/sec: 242.131
# INFO:tensorflow:loss = 46230.645, step = 5601 (0.414 sec)
# INFO:tensorflow:global_step/sec: 287.356
# INFO:tensorflow:loss = 42099.086, step = 5701 (0.347 sec)
# INFO:tensorflow:global_step/sec: 334.448
# INFO:tensorflow:loss = 46117.617, step = 5801 (0.299 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 44988.58, step = 5901 (0.303 sec)
# INFO:tensorflow:global_step/sec: 331.126
# INFO:tensorflow:loss = 49501.188, step = 6001 (0.302 sec)
# INFO:tensorflow:global_step/sec: 333.333
# INFO:tensorflow:loss = 43302.645, step = 6101 (0.300 sec)
# INFO:tensorflow:global_step/sec: 333.333
# INFO:tensorflow:loss = 46256.79, step = 6201 (0.300 sec)
# INFO:tensorflow:global_step/sec: 327.869
# INFO:tensorflow:loss = 45254.62, step = 6301 (0.305 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 47965.688, step = 6401 (0.304 sec)
# INFO:tensorflow:global_step/sec: 334.448
# INFO:tensorflow:loss = 33771.145, step = 6501 (0.298 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 36744.66, step = 6601 (0.304 sec)
# INFO:tensorflow:global_step/sec: 303.03
# INFO:tensorflow:loss = 42387.844, step = 6701 (0.329 sec)
# INFO:tensorflow:global_step/sec: 334.448
# INFO:tensorflow:loss = 44037.656, step = 6801 (0.299 sec)
# INFO:tensorflow:global_step/sec: 333.333
# INFO:tensorflow:loss = 52247.4, step = 6901 (0.300 sec)
# INFO:tensorflow:global_step/sec: 334.448
# INFO:tensorflow:loss = 41825.332, step = 7001 (0.299 sec)
# INFO:tensorflow:global_step/sec: 335.571
# INFO:tensorflow:loss = 38426.125, step = 7101 (0.298 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 45224.625, step = 7201 (0.303 sec)
# INFO:tensorflow:global_step/sec: 331.126
# INFO:tensorflow:loss = 35070.812, step = 7301 (0.302 sec)
# INFO:tensorflow:global_step/sec: 328.947
# INFO:tensorflow:loss = 40705.727, step = 7401 (0.304 sec)
# INFO:tensorflow:global_step/sec: 328.947
# INFO:tensorflow:loss = 35861.473, step = 7501 (0.304 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 41394.934, step = 7601 (0.303 sec)
# INFO:tensorflow:global_step/sec: 332.226
# INFO:tensorflow:loss = 45345.8, step = 7701 (0.301 sec)
# INFO:tensorflow:global_step/sec: 331.126
# INFO:tensorflow:loss = 51210.79, step = 7801 (0.302 sec)
# INFO:tensorflow:global_step/sec: 333.333
# INFO:tensorflow:loss = 44407.492, step = 7901 (0.300 sec)
# INFO:tensorflow:global_step/sec: 335.57
# INFO:tensorflow:loss = 32128.904, step = 8001 (0.299 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 37837.12, step = 8101 (0.302 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 38801.27, step = 8201 (0.308 sec)
# INFO:tensorflow:global_step/sec: 311.527
# INFO:tensorflow:loss = 35892.53, step = 8301 (0.320 sec)
# INFO:tensorflow:global_step/sec: 314.465
# INFO:tensorflow:loss = 49359.72, step = 8401 (0.318 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 33434.977, step = 8501 (0.310 sec)
# INFO:tensorflow:global_step/sec: 331.126
# INFO:tensorflow:loss = 26618.31, step = 8601 (0.302 sec)
# INFO:tensorflow:global_step/sec: 332.226
# INFO:tensorflow:loss = 36209.0, step = 8701 (0.301 sec)
# INFO:tensorflow:global_step/sec: 334.448
# INFO:tensorflow:loss = 51727.723, step = 8801 (0.300 sec)
# INFO:tensorflow:global_step/sec: 332.226
# INFO:tensorflow:loss = 38984.17, step = 8901 (0.300 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 52668.668, step = 9001 (0.304 sec)
# INFO:tensorflow:global_step/sec: 328.947
# INFO:tensorflow:loss = 38227.22, step = 9101 (0.304 sec)
# INFO:tensorflow:global_step/sec: 333.333
# INFO:tensorflow:loss = 37885.32, step = 9201 (0.300 sec)
# INFO:tensorflow:global_step/sec: 331.126
# INFO:tensorflow:loss = 43072.848, step = 9301 (0.302 sec)
# INFO:tensorflow:global_step/sec: 334.448
# INFO:tensorflow:loss = 41310.59, step = 9401 (0.298 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 47416.652, step = 9501 (0.303 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 49956.746, step = 9601 (0.303 sec)
# INFO:tensorflow:global_step/sec: 332.226
# INFO:tensorflow:loss = 35311.207, step = 9701 (0.302 sec)
# INFO:tensorflow:global_step/sec: 331.126
# INFO:tensorflow:loss = 56292.918, step = 9801 (0.301 sec)
# INFO:tensorflow:global_step/sec: 332.226
# INFO:tensorflow:loss = 40003.09, step = 9901 (0.302 sec)
# INFO:tensorflow:global_step/sec: 254.453
# INFO:tensorflow:loss = 37522.55, step = 10001 (0.392 sec)
# INFO:tensorflow:global_step/sec: 273.224
# INFO:tensorflow:loss = 41895.402, step = 10101 (0.366 sec)
# INFO:tensorflow:global_step/sec: 310.559
# INFO:tensorflow:loss = 37963.85, step = 10201 (0.322 sec)
# INFO:tensorflow:global_step/sec: 333.333
# INFO:tensorflow:loss = 43607.617, step = 10301 (0.300 sec)
# INFO:tensorflow:global_step/sec: 330.033
# INFO:tensorflow:loss = 39698.812, step = 10401 (0.303 sec)
# INFO:tensorflow:global_step/sec: 311.526
# INFO:tensorflow:loss = 44356.22, step = 10501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 286.533
# INFO:tensorflow:loss = 38236.734, step = 10601 (0.350 sec)
# INFO:tensorflow:global_step/sec: 304.878
# INFO:tensorflow:loss = 50016.67, step = 10701 (0.329 sec)
# INFO:tensorflow:global_step/sec: 230.947
# INFO:tensorflow:loss = 42570.926, step = 10801 (0.431 sec)
# INFO:tensorflow:global_step/sec: 299.401
# INFO:tensorflow:loss = 42178.492, step = 10901 (0.334 sec)
# INFO:tensorflow:global_step/sec: 278.552
# INFO:tensorflow:loss = 43521.902, step = 11001 (0.360 sec)
# INFO:tensorflow:global_step/sec: 295.858
# INFO:tensorflow:loss = 41164.195, step = 11101 (0.337 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 27239.863, step = 11201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 39728.055, step = 11301 (0.314 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 48041.12, step = 11401 (0.312 sec)
# INFO:tensorflow:global_step/sec: 300.3
# INFO:tensorflow:loss = 45445.08, step = 11501 (0.334 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 33220.145, step = 11601 (0.313 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 44024.246, step = 11701 (0.313 sec)
# INFO:tensorflow:global_step/sec: 318.472
# INFO:tensorflow:loss = 40756.01, step = 11801 (0.313 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 48742.65, step = 11901 (0.309 sec)
# INFO:tensorflow:global_step/sec: 323.624
# INFO:tensorflow:loss = 38693.645, step = 12001 (0.309 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 35308.13, step = 12101 (0.313 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 47512.156, step = 12201 (0.307 sec)
# INFO:tensorflow:global_step/sec: 317.46
# INFO:tensorflow:loss = 37003.363, step = 12301 (0.314 sec)
# INFO:tensorflow:global_step/sec: 322.58
# INFO:tensorflow:loss = 48645.54, step = 12401 (0.310 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 42497.95, step = 12501 (0.308 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 46080.355, step = 12601 (0.307 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 41148.555, step = 12701 (0.313 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 34755.43, step = 12801 (0.312 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 51925.117, step = 12901 (0.314 sec)
# INFO:tensorflow:global_step/sec: 317.46
# INFO:tensorflow:loss = 44098.004, step = 13001 (0.314 sec)
# INFO:tensorflow:global_step/sec: 300.3
# INFO:tensorflow:loss = 38360.617, step = 13101 (0.333 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 35146.074, step = 13201 (0.308 sec)
# INFO:tensorflow:global_step/sec: 308.642
# INFO:tensorflow:loss = 42941.63, step = 13301 (0.324 sec)
# INFO:tensorflow:global_step/sec: 317.46
# INFO:tensorflow:loss = 56039.594, step = 13401 (0.316 sec)
# INFO:tensorflow:global_step/sec: 311.527
# INFO:tensorflow:loss = 47038.63, step = 13501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 40540.137, step = 13601 (0.312 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 44841.082, step = 13701 (0.311 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 40954.11, step = 13801 (0.312 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 50253.277, step = 13901 (0.313 sec)
# INFO:tensorflow:global_step/sec: 322.58
# INFO:tensorflow:loss = 39151.625, step = 14001 (0.310 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 34706.48, step = 14101 (0.310 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 44973.055, step = 14201 (0.313 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 40012.055, step = 14301 (0.308 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 44368.08, step = 14401 (0.313 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 44720.33, step = 14501 (0.313 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 41304.164, step = 14601 (0.311 sec)
# INFO:tensorflow:global_step/sec: 294.118
# INFO:tensorflow:loss = 51227.953, step = 14701 (0.339 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 43524.85, step = 14801 (0.311 sec)
# INFO:tensorflow:global_step/sec: 310.559
# INFO:tensorflow:loss = 48969.883, step = 14901 (0.322 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 43902.773, step = 15001 (0.307 sec)
# INFO:tensorflow:global_step/sec: 323.624
# INFO:tensorflow:loss = 42697.29, step = 15101 (0.309 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 36155.78, step = 15201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 35979.47, step = 15301 (0.310 sec)
# INFO:tensorflow:global_step/sec: 326.797
# INFO:tensorflow:loss = 36201.445, step = 15401 (0.306 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 38575.676, step = 15501 (0.312 sec)
# INFO:tensorflow:global_step/sec: 326.798
# INFO:tensorflow:loss = 44059.01, step = 15601 (0.306 sec)
# INFO:tensorflow:global_step/sec: 322.58
# INFO:tensorflow:loss = 40457.555, step = 15701 (0.310 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 46893.32, step = 15801 (0.314 sec)
# INFO:tensorflow:global_step/sec: 323.624
# INFO:tensorflow:loss = 41729.113, step = 15901 (0.310 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 46549.3, step = 16001 (0.307 sec)
# INFO:tensorflow:global_step/sec: 318.472
# INFO:tensorflow:loss = 32709.24, step = 16101 (0.314 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 42290.984, step = 16201 (0.310 sec)
# INFO:tensorflow:global_step/sec: 299.401
# INFO:tensorflow:loss = 47047.152, step = 16301 (0.333 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 55297.566, step = 16401 (0.313 sec)
# INFO:tensorflow:global_step/sec: 314.465
# INFO:tensorflow:loss = 40530.18, step = 16501 (0.319 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 42224.008, step = 16601 (0.311 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 44821.87, step = 16701 (0.311 sec)
# INFO:tensorflow:global_step/sec: 323.624
# INFO:tensorflow:loss = 43655.957, step = 16801 (0.309 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 43848.81, step = 16901 (0.311 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 38534.574, step = 17001 (0.311 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 43424.797, step = 17101 (0.313 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 41610.2, step = 17201 (0.313 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 43812.18, step = 17301 (0.310 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 38279.637, step = 17401 (0.313 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 37253.87, step = 17501 (0.313 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 35971.832, step = 17601 (0.312 sec)
# INFO:tensorflow:global_step/sec: 317.46
# INFO:tensorflow:loss = 54962.07, step = 17701 (0.314 sec)
# INFO:tensorflow:global_step/sec: 322.58
# INFO:tensorflow:loss = 42435.207, step = 17801 (0.310 sec)
# INFO:tensorflow:global_step/sec: 300.3
# INFO:tensorflow:loss = 41227.72, step = 17901 (0.333 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 47313.785, step = 18001 (0.311 sec)
# INFO:tensorflow:global_step/sec: 308.642
# INFO:tensorflow:loss = 44651.273, step = 18101 (0.324 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 47238.77, step = 18201 (0.313 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 34697.63, step = 18301 (0.311 sec)
# INFO:tensorflow:global_step/sec: 323.624
# INFO:tensorflow:loss = 42413.71, step = 18401 (0.308 sec)
# INFO:tensorflow:global_step/sec: 313.48
# INFO:tensorflow:loss = 37884.76, step = 18501 (0.319 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 41860.29, step = 18601 (0.311 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 43458.113, step = 18701 (0.315 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 46244.508, step = 18801 (0.312 sec)
# INFO:tensorflow:global_step/sec: 328.947
# INFO:tensorflow:loss = 40482.105, step = 18901 (0.304 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 42524.94, step = 19001 (0.312 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 47201.727, step = 19101 (0.310 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 46221.605, step = 19201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 42311.625, step = 19301 (0.312 sec)
# INFO:tensorflow:global_step/sec: 326.797
# INFO:tensorflow:loss = 37387.086, step = 19401 (0.306 sec)
# INFO:tensorflow:global_step/sec: 299.401
# INFO:tensorflow:loss = 33119.426, step = 19501 (0.334 sec)
# INFO:tensorflow:global_step/sec: 322.581
# INFO:tensorflow:loss = 39767.234, step = 19601 (0.310 sec)
# INFO:tensorflow:global_step/sec: 316.456
# INFO:tensorflow:loss = 35446.082, step = 19701 (0.316 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 36768.63, step = 19801 (0.309 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 35530.49, step = 19901 (0.308 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 38728.992, step = 20001 (0.307 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 44697.434, step = 20101 (0.311 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 42821.098, step = 20201 (0.307 sec)
# INFO:tensorflow:global_step/sec: 279.33
# INFO:tensorflow:loss = 38483.223, step = 20301 (0.358 sec)
# INFO:tensorflow:global_step/sec: 295.858
# INFO:tensorflow:loss = 38460.777, step = 20401 (0.338 sec)
# INFO:tensorflow:global_step/sec: 315.458
# INFO:tensorflow:loss = 38134.21, step = 20501 (0.317 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 43162.11, step = 20601 (0.312 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 48836.35, step = 20701 (0.312 sec)
# INFO:tensorflow:global_step/sec: 320.513
# INFO:tensorflow:loss = 48543.0, step = 20801 (0.311 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 53233.38, step = 20901 (0.313 sec)
# INFO:tensorflow:global_step/sec: 316.456
# INFO:tensorflow:loss = 51193.562, step = 21001 (0.317 sec)
# INFO:tensorflow:global_step/sec: 303.951
# INFO:tensorflow:loss = 45074.81, step = 21101 (0.328 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 31066.4, step = 21201 (0.314 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 39206.492, step = 21301 (0.313 sec)
# INFO:tensorflow:global_step/sec: 326.797
# INFO:tensorflow:loss = 48698.87, step = 21401 (0.306 sec)
# INFO:tensorflow:global_step/sec: 322.58
# INFO:tensorflow:loss = 44263.71, step = 21501 (0.310 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 41246.344, step = 21601 (0.311 sec)
# INFO:tensorflow:global_step/sec: 326.798
# INFO:tensorflow:loss = 42284.69, step = 21701 (0.306 sec)
# INFO:tensorflow:global_step/sec: 328.947
# INFO:tensorflow:loss = 42797.223, step = 21801 (0.304 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 43621.613, step = 21901 (0.314 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 36034.637, step = 22001 (0.308 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 49477.363, step = 22101 (0.307 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 45937.78, step = 22201 (0.309 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 43468.504, step = 22301 (0.306 sec)
# INFO:tensorflow:global_step/sec: 321.543
# INFO:tensorflow:loss = 46373.367, step = 22401 (0.311 sec)
# INFO:tensorflow:global_step/sec: 313.48
# INFO:tensorflow:loss = 43053.1, step = 22501 (0.319 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 54357.1, step = 22601 (0.314 sec)
# INFO:tensorflow:global_step/sec: 297.619
# INFO:tensorflow:loss = 46923.9, step = 22701 (0.336 sec)
# INFO:tensorflow:global_step/sec: 326.798
# INFO:tensorflow:loss = 42067.39, step = 22801 (0.305 sec)
# INFO:tensorflow:global_step/sec: 314.465
# INFO:tensorflow:loss = 31734.713, step = 22901 (0.318 sec)
# INFO:tensorflow:global_step/sec: 321.544
# INFO:tensorflow:loss = 39587.516, step = 23001 (0.311 sec)
# INFO:tensorflow:global_step/sec: 323.625
# INFO:tensorflow:loss = 37498.684, step = 23101 (0.309 sec)
# INFO:tensorflow:global_step/sec: 319.489
# INFO:tensorflow:loss = 41759.79, step = 23201 (0.313 sec)
# INFO:tensorflow:global_step/sec: 322.58
# INFO:tensorflow:loss = 45957.996, step = 23301 (0.310 sec)
# INFO:tensorflow:global_step/sec: 324.675
# INFO:tensorflow:loss = 42909.035, step = 23401 (0.309 sec)
# INFO:tensorflow:global_step/sec: 310.559
# INFO:tensorflow:loss = 42402.61, step = 23501 (0.321 sec)
# INFO:tensorflow:global_step/sec: 318.471
# INFO:tensorflow:loss = 39404.92, step = 23601 (0.314 sec)
# INFO:tensorflow:global_step/sec: 326.798
# INFO:tensorflow:loss = 45618.793, step = 23701 (0.306 sec)
# INFO:tensorflow:global_step/sec: 311.526
# INFO:tensorflow:loss = 34602.43, step = 23801 (0.322 sec)
# INFO:tensorflow:global_step/sec: 325.733
# INFO:tensorflow:loss = 36727.23, step = 23901 (0.306 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into trained_models/reg-model-06\model.ckpt.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-24-08:45:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06\model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-24-08:45:57
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 94.22723, global_step = 24000, label/mean = 1.4932353, loss = 47113.613, prediction/mean = 1.5614183
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24000: trained_models/reg-model-06\model.ckpt-24000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: ['serving_default', 'regression']
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06\model.ckpt-24000
# WARNING:tensorflow:From D:\ProgramLanguageCore\Python\anaconda351\lib\site-packages\tensorflow\python\estimator\estimator.py:1044: calling SavedModelBuilder.add_meta_graph_and_variables (from tensorflow.python.saved_model.builder_impl) with legacy_init_op is deprecated and will be removed in a future version.
# Instructions for updating:
# Pass your op to the equivalent parameter main_op instead.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: trained_models/reg-model-06\export\estimate\temp-b'1543049157'\saved_model.pbtxt
# INFO:tensorflow:Loss for final step: 32714.871.
# .......................................
# Experiment finished at 08:45:59
#
# Experiment elapsed time: 83.255 seconds

# %% [markdown]
# ## 6. Evaluate the Model

# %%
TRAIN_SIZE = 12000
VALID_SIZE = 3000
TEST_SIZE = 5000
train_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TRAIN_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TRAIN_SIZE)

valid_input_fn = lambda: tfrecods_input_fn(files_name_pattern= VALID_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= VALID_SIZE)

test_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TEST_SIZE)

estimator = create_estimator(run_config, hparams)

train_results = estimator.evaluate(input_fn=train_input_fn, steps=1)
train_rmse = round(math.sqrt(train_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Train RMSE: {} - {}".format(train_rmse, train_results))
print("############################################################################################")

valid_results = estimator.evaluate(input_fn=valid_input_fn, steps=1)
valid_rmse = round(math.sqrt(valid_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Valid RMSE: {} - {}".format(valid_rmse,valid_results))
print("############################################################################################")

test_results = estimator.evaluate(input_fn=test_input_fn, steps=1)
test_rmse = round(math.sqrt(test_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Test RMSE: {} - {}".format(test_rmse, test_results))
print("############################################################################################")
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'trained_models/reg-model-06', '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000000003311A860>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 12000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-24-08:46:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06\model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-11-24-08:46:22
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 83.61736, global_step = 24000, label/mean = 1.3935989, loss = 1003408.4, prediction/mean = 1.3622133
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24000: trained_models/reg-model-06\model.ckpt-24000
#
# ############################################################################################
# # Train RMSE: 9.14425 - {'average_loss': 83.61736, 'label/mean': 1.3935989, 'loss': 1003408.4, 'prediction/mean': 1.3622133, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 3000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-24-08:46:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06\model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-11-24-08:46:23
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 94.22723, global_step = 24000, label/mean = 1.493235, loss = 282681.7, prediction/mean = 1.5614179
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24000: trained_models/reg-model-06\model.ckpt-24000
#
# ############################################################################################
# # Valid RMSE: 9.70707 - {'average_loss': 94.22723, 'label/mean': 1.493235, 'loss': 282681.7, 'prediction/mean': 1.5614179, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-24-08:46:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06\model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2018-11-24-08:46:25
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 93.4444, global_step = 24000, label/mean = 1.0653467, loss = 467221.97, prediction/mean = 1.1817776
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24000: trained_models/reg-model-06\model.ckpt-24000
#
# ############################################################################################
# # Test RMSE: 9.66666 - {'average_loss': 93.4444, 'label/mean': 1.0653467, 'loss': 467221.97, 'prediction/mean': 1.1817776, 'global_step': 24000}
# ############################################################################################

# %% [markdown]
# ## 7. Prediction

# %%
import itertools

predict_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 5)

predictions = estimator.predict(input_fn=predict_input_fn)
values = list(map(lambda item: item["predictions"][0],list(itertools.islice(predictions, 5))))
print()
print("Predicted Values: {}".format(values))
# Out:
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5
# Epoch Count: None
# Mode: infer
# Shuffle: False
# ================
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06\model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Predicted Values: [50.57643, -3.1678717, 18.039553, 2.8187575, 2.5548038]

# %% [markdown]
# ## Serving via the Saved Model

# %%
import os

export_dir = model_dir +"/export/estimate"

saved_model_dir = export_dir + "/" + os.listdir(path=export_dir)[-1] 

print(saved_model_dir)

predictor_fn = tf.contrib.predictor.from_saved_model(
    export_dir = saved_model_dir,
    signature_def_key="predict"
)

output = predictor_fn({'csv_rows': ["0.5,1,ax01,bx02", "-0.5,-1,ax02,bx02"]})
print(output)
# Out:
# trained_models/reg-model-06/export/estimate/1543049157
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-06/export/estimate/1543049157\variables\variables
# {'predictions': array([[ 66.432556],
#        [-13.668721]], dtype=float32)}

# %%
saved_model_dir
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b1b58a385504> in <module>()
# ----> 1 saved_model_dir
#
# NameError: name 'saved_model_dir' is not defined

# %%
export_dir
# Out:
# 'trained_models/reg-model-06/export/estimate'

# %%
 os.listdir(path=export_dir)
# Out:
# []
